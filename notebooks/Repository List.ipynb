# %%
# %%writefile ../src/__init__.py
from pprint import pprint

from git import Repo as Git
from github import Github
from gitlab import Gitlab

# %%
# %%writefile ../src/config.py
import os

# Config
GITHUB_USERNAME = os.getenv('GITHUB_USERNAME')
GITHUB_TOKEN = os.getenv('GITHUB_TOKEN')
GITLAB_USERNAME =  os.getenv('GITLAB_USERNAME')
GITLAB_TOKEN = os.getenv('GITLAB_TOKEN')

PROGRAMMING_ROOT = '../../../..'

# %%
# %%writefile ../src/utils.py
def get_repo_name_from_url(url: str) -> str:
    last_slash_index = url.rfind("/")
    last_suffix_index = url.rfind(".git")
    if last_suffix_index < 0 or last_suffix_index != len(url)-4:
        last_suffix_index = len(url)
    if last_slash_index < 0 or last_suffix_index <= last_slash_index:
        raise Exception("Badly formatted url {}".format(url))

    return url[last_slash_index + 1:last_suffix_index]

# %%
# Github Login
github = Github(GITHUB_USERNAME, GITHUB_TOKEN)
user = github.get_user()
pprint(user.login)
# Out:
# 'VikashKothary'

# %%
# Get list of local repos
my_files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(PROGRAMMING_ROOT):
    for directory in d:
        if '.git' == directory:
            my_files.append(r)
pprint(my_files)
# Out:
# ['../../../../client-vikashkothary/devops-ansible/ansible-laptop-macos',
#  '../../../../client-vikashkothary/devops-ansible/setup-scripts',
#  '../../../../client-vikashkothary/devops-ansible/ansible-redhat-workshop',
#  '../../../../client-vikashkothary/devops-ansible/ansible-setup',
#  '../../../../client-vikashkothary/projects-youtube/youtube-upload',
#  '../../../../client-vikashkothary/projects-youtube/youtube-dl',
#  '../../../../client-vikashkothary/devops-configs/dotyaml',
#  '../../../../client-vikashkothary/org/org-gists',
#  '../../../../client-vikashkothary/org/org-settings',
#  '../../../../client-vikashkothary/training-coursera/coursera-deep-learning',
#  '../../../../client-vikashkothary/training-coursera/coursera-applied-data-science',
#  '../../../../client-vikashkothary/devops-docker/docker-openjdk',
#  '../../../../client-vikashkothary/devops-docker/docker-ngrok',
#  '../../../../client-vikashkothary/devops-docker/docker-golang',
#  '../../../../client-vikashkothary/devops-docker/docker-monicahq',
#  '../../../../client-vikashkothary/devops-docker/docker-postgresql',
#  '../../../../client-vikashkothary/devops-docker/docker-mailslurper',
#  '../../../../client-vikashkothary/devops-docker/docker-redis',
#  '../../../../client-vikashkothary/devops-docker/docker-nodejs',
#  '../../../../client-vikashkothary/devops-docker/docker-latex',
#  '../../../../client-vikashkothary/devops-docker/docker-alpine',
#  '../../../../client-vikashkothary/devops-docker/docker-localtunnel',
#  '../../../../client-vikashkothary/devops-docker/docker-jenkins',
#  '../../../../client-vikashkothary/devops-docker/docker-python',
#  '../../../../client-vikashkothary/devops-docker/docker-gitlab',
#  '../../../../client-vikashkothary/devops-docker/docker-dnsmasq',
#  '../../../../client-vikashkothary/devops-docker/docker-backup',
#  '../../../../client-vikashkothary/devops-docker/docker-ghost',
#  '../../../../client-vikashkothary/devops-docker/docker-nginx',
#  '../../../../client-vikashkothary/devops-docker/docker-nginx-manager',
#  '../../../../client-vikashkothary/devops-docker/docker-plex',
#  '../../../../client-vikashkothary/devops-docker/docker-apache',
#  '../../../../client-vikashkothary/devops-docker/docker-ubuntu',
#  '../../../../client-vikashkothary/devops-docker/docker-ruby',
#  '../../../../client-vikashkothary/devops-docker/docker-gollum',
#  '../../../../client-vikashkothary/devops-docker/docker-matlab',
#  '../../../../client-vikashkothary/architect-style-guide/javascript',
#  '../../../../client-vikashkothary/projects-anki/ankicommunity.github.io',
#  '../../../../client-vikashkothary/projects-anki/anki-syncd-server',
#  '../../../../client-vikashkothary/projects-anki/anki-markdown',
#  '../../../../client-vikashkothary/projects-anki/anki-core',
#  '../../../../client-vikashkothary/projects-anki/anki-sync-server',
#  '../../../../client-vikashkothary/projects-kodi/plugin.video.hotstar2',
#  '../../../../client-vikashkothary/projects-kodi/plugin.audio.googleplaymusic',
#  '../../../../client-vikashkothary/projects-kodi/plugin.video.netflixbmc',
#  '../../../../client-vikashkothary/projects-kodi/plugin.script.tvtime',
#  '../../../../client-vikashkothary/projects-kodi/plugin.video.hotstar',
#  '../../../../client-vikashkothary/projects-kodi/kodi-cli-python',
#  '../../../../client-vikashkothary/projects-kodi/plugin.video.crunchyroll',
#  '../../../../client-vikashkothary/projects-kodi/plugin.video.netflix',
#  '../../../../client-vikashkothary/projects-kodi/plugin.video.skygo',
#  '../../../../client-vikashkothary/frontend-react/react-iframe',
#  '../../../../client-vikashkothary/frontend-react/react-contextmenu',
#  '../../../../client-vikashkothary/frontend-react/react-bootstrap',
#  '../../../../client-vikashkothary/client-other/shivam-cleaningscript',
#  '../../../../client-vikashkothary/client-other/travel-map-python',
#  '../../../../client-vikashkothary/client-other/cash-auditor',
#  '../../../../client-vikashkothary/projects-perfectionist/pomodoro-timer',
#  '../../../../client-vikashkothary/projects-perfectionist/pomodoro-clock',
#  '../../../../client-vikashkothary/projects-perfectionist/pomodoro-calendar',
#  '../../../../client-vikashkothary/backend-swagger/swagger-tinder/legacy/python',
#  '../../../../client-vikashkothary/backend-swagger/swagger-aem',
#  '../../../../client-vikashkothary/backend-swagger/swagger-everyoneactive/legacy/python',
#  '../../../../client-vikashkothary/backend-swagger/swagger-myfitnesspal',
#  '../../../../client-vikashkothary/backend-swagger/swagger-myfitnesspal/legacy/python',
#  '../../../../client-vikashkothary/backend-swagger/swagger-fitbit/legacy/python',
#  '../../../../client-vikashkothary/projects-university/university-market-information-service',
#  '../../../../client-vikashkothary/projects-university/university-sunka',
#  '../../../../client-vikashkothary/projects-university/university-walk',
#  '../../../../client-vikashkothary/projects-university/university-pracoursework',
#  '../../../../client-vikashkothary/projects-university/university-languine',
#  '../../../../client-vikashkothary/projects-university/university-jswing-library',
#  '../../../../client-vikashkothary/projects-university/university-android-workshop',
#  '../../../../client-vikashkothary/projects-university/university-pacman',
#  '../../../../client-vikashkothary/projects-university/university-kinba',
#  '../../../../client-vikashkothary/devops-git/git-subrepo',
#  '../../../../client-vikashkothary/devops-git/git-project-gantt',
#  '../../../../client-vikashkothary/devops-git/git-org-flow',
#  '../../../../client-vikashkothary/devops-git/git-wiki-flow',
#  '../../../../client-vikashkothary/devops-git/git-multirepo',
#  '../../../../client-vikashkothary/devops-git/git-forked-issues',
#  '../../../../client-vikashkothary/projects-osos/osos-dating-backend',
#  '../../../../client-vikashkothary/projects-osos/clock-app',
#  '../../../../client-vikashkothary/projects-osos/messenger-plus',
#  '../../../../client-vikashkothary/projects-osos/osos-cinema',
#  '../../../../client-vikashkothary/projects-osos/osostogether.github.io',
#  '../../../../client-vikashkothary/projects-osos/settings-app',
#  '../../../../client-vikashkothary/projects-osos/background-app',
#  '../../../../client-vikashkothary/projects-osos/osos-dating-frontend',
#  '../../../../client-vikashkothary/projects-jsonresume/jsonresume-theme-boilerplate',
#  '../../../../client-vikashkothary/projects-jsonresume/latex-awesome-cv',
#  '../../../../client-vikashkothary/projects-jsonresume/jsonresume-theme-business-card',
#  '../../../../client-vikashkothary/projects-jsonresume/resume-cli',
#  '../../../../client-vikashkothary/projects-jsonresume/jsonschema',
#  '../../../../client-vikashkothary/projects-jsonresume/resumeToPDF',
#  '../../../../client-vikashkothary/projects-jsonresume/resumeToMarkdown',
#  '../../../../client-vikashkothary/projects-jsonresume/resume-schema',
#  '../../../../client-vikashkothary/projects-personalwebsite',
#  '../../../../client-vikashkothary/projects-personalwebsite/vikashkothary-frontend',
#  '../../../../client-vikashkothary/projects-personalwebsite/vikashkothary-aem',
#  '../../../../client-vikashkothary/architect-yeoman/generator-react-multi-platform',
#  '../../../../client-vikashkothary/architect-yeoman/generator-chrome-extension',
#  '../../../../client-vikashkothary/architect-yeoman/generator-kotlin-multi-platform',
#  '../../../../client-vikashkothary/architect-yeoman/generator-react-native-multi-platform',
#  '../../../../client-vikashkothary/architect-yeoman/generator-python-package',
#  '../../../../client-vikashkothary/architect-yeoman/generator-open-source-docs',
#  '../../../../client-vikashkothary/architect-yeoman/generator-yeoman-generator',
#  '../../../../client-vikashkothary/architect-yeoman/fullstack',
#  '../../../../client-vikashkothary/architect-yeoman/generator-html5-boilerplate',
#  '../../../../client-vikashkothary/architect-yeoman/generator-fitbit-app',
#  '../../../../client-vikashkothary/projects-ocean/ocean-emails',
#  '../../../../client-vikashkothary/projects-ocean/ocean-faces',
#  '../../../../client-vikashkothary/projects-ocean/ocean-voices',
#  '../../../../client-vikashkothary/projects-joplin/joplin',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-mail-plus',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-jobie-backend',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-muzact',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-translatify',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-square-chat',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-learnit',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-british-express',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-hackameetup',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-now',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-skynet-frontend',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-skynet-backend',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-natural-git',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-movie-narrator',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-veggie-on-rails',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-jobie-frontend',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-anastasia',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-my-pet-parrot',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-museful',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-wheelx',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-gemini',
#  '../../../../client-vikashkothary/projects-hackathon/hackathon-gemini/gemini-frontend/node_modules/gh-pages/.cache/github.com!Vikash-Kothary!hacktrain6-gemini',
#  '../../../../client-adobe/training-adobe/adobe-lunchandlearn-python',
#  '../../../../client-adobe/training-adobe/adobe-platform-enablement',
#  '../../../../client-adobe/projects-adobe/aem-spa-project-archetype',
#  '../../../../client-adobe/projects-adobe/aem-admin-console',
#  '../../../../client-adobe/projects-adobe/aem-developer-bootstrap',
#  '../../../../client-adobe/projects-adobe/aem-developer-bootstrap/code/test-bootstrap',
#  '../../../../client-adobe/projects-adobe/bastien-poc',
#  '../../../../client-adobe/projects-adobe/aem-maven-archetype',
#  '../../../../client-adobe/projects-adobe/aem-sass-compiler',
#  '../../../../client-adobe/projects-adobe/aem-coding-standards',
#  '../../../../client-adobe/projects-adobe/aem-cmd',
#  '../../../../client-adobe/projects-adobe/adobe-hackathon-graphql/code',
#  '../../../../client-adobe/projects-adobe/aem-devops-cli/aem-cli-groovy',
#  '../../../../client-adobe/projects-adobe/aem-devops-cli/aem-cli-groovy/tmp-api',
#  '../../../../client-adobe/projects-adobe/aem-devops-cli/aem-cli-go',
#  '../../../../client-adobe/projects-adobe/aem-guides-wknd',
#  '../../../../client-adobe/projects-adobe/aem-development-guidelines',
#  '../../../../client-adobe/projects-adobe/adobe-hackathon-aem',
#  '../../../../client-adobe/projects-informa-ge/informa-wiki',
#  '../../../../client-adobe/projects-informa-ge/informa-servers',
#  '../../../../client-adobe/projects-informa-ge/informa-frontend',
#  '../../../../client-adobe/projects-informa-ge/informa-functions',
#  '../../../../client-adobe/projects-informa-ge/informa-aem',
#  '../../../../client-adobe/projects-informa-ge/informa-content',
#  '../../../../client-adobe/projects-informa-ge/informa-backend',
#  '../../../../client-adobe/projects-acs-awards/acs-awards-servers',
#  '../../../../client-adobe/projects-acs-awards/acs-awards-wiki',
#  '../../../../client-adobe/projects-acs-awards/acs-awards-aem',
#  '../../../../client-adobe/architect-lazybones/lazybones-aem-templates',
#  '../../../../client-adobe/architect-lazybones/lazybones',
#  '../../../../unordered/acs-confluence',
#  '../../../../unordered/LanguineCMS',
#  '../../../../unordered/productivity-app-android',
#  '../../../../unordered/vikash-kothary.github.io',
#  '../../../../unordered/aem6.5-live-trials/aem-6.5-training/files',
#  '../../../../unordered/aem6.5-live-trials/aem-6.5-training/react',
#  '../../../../unordered/aem6.5-live-trials/aem-6.5-live-trials',
#  '../../../../unordered/aem6.5-live-trials/aem-6.5-live-trials/cloudmanager_SC/aem65lt',
#  '../../../../unordered/aem6.5-live-trials/SJCImplementors',
#  '../../../../unordered/ocean-dating-typescript',
#  '../../../../unordered/adls-aem-training',
#  '../../../../unordered/Maven-Vault-Checkout-Plugin',
#  '../../../../unordered/ocean-jobs',
#  '../../../../unordered/financial-freedom-python',
#  '../../../../unordered/ocean-obtain-python',
#  '../../../../unordered/kanbanist',
#  '../../../../unordered/life-app-android',
#  '../../../../unordered/osos-file-formats',
#  '../../../../unordered/looking-glass-rpg',
#  '../../../../unordered/kclindiasociety-python',
#  '../../../../unordered/acs-docker/docker-aem6.5',
#  '../../../../unordered/acs-docker/cni-dam-docker',
#  '../../../../unordered/vikash-kothary-github-io',
#  '../../../../unordered/documentation-acs/start-here',
#  '../../../../unordered/ocean-accounts-python',
#  '../../../../unordered/ocean-social-typescript']

# %%
# Remove child repos
for file in my_files:
    if len(file.split('/')) > 5:
#         pprint(f'Removing ${file}')
        my_files.remove(file)
# pprint(my_files)

# %%
# Get repo namee for all local repos
my_local_repos = []
for file in my_files:
    repo = dict()
    local_repo = Git(file)
    if len(local_repo.remotes) == 0:
        repo['repo_name'] = os.path.basename(local_repo.working_dir)
    else:
        repo['remote_url'] = local_repo.remotes[0].url
        repo['repo_name'] = get_repo_name_from_url(repo['remote_url'])
    my_local_repos.append(repo)
pprint(my_local_repos)
# Out:
# [{'remote_url': 'https://github.com/Vikash-Kothary/setup-scripts.git',
#   'repo_name': 'setup-scripts'},
#  {'remote_url': 'git@github.com:Vikash-Kothary/setup-scripts.git',
#   'repo_name': 'setup-scripts'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/youtube-dl.git',
#   'repo_name': 'youtube-dl'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/org-gists.git',
#   'repo_name': 'org-gists'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/deep-learning-coursera',
#   'repo_name': 'deep-learning-coursera'},
#  {'remote_url': 'https://github.com/vikash-kothary/docker-java',
#   'repo_name': 'docker-java'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/docker-golang',
#   'repo_name': 'docker-golang'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/docker-postgresql',
#   'repo_name': 'docker-postgresql'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/docker-redis',
#   'repo_name': 'docker-redis'},
#  {'remote_url': 'https://github.com/blang/latex-docker',
#   'repo_name': 'latex-docker'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/docker-localtunnel.git',
#   'repo_name': 'docker-localtunnel'},
#  {'remote_url': 'https://github.com/VikashKothary/docker-python',
#   'repo_name': 'docker-python'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/docker-dnsmasq.git',
#   'repo_name': 'docker-dnsmasq'},
#  {'remote_url': 'https://github.com/vikash-kothary/docker-ghost',
#   'repo_name': 'docker-ghost'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/nginx-proxy-manager',
#   'repo_name': 'nginx-proxy-manager'},
#  {'repo_name': 'docker-apache'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/docker-ruby',
#   'repo_name': 'docker-ruby'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/docker-matlab',
#   'repo_name': 'docker-matlab'},
#  {'remote_url': 'https://github.com/ankicommunity/ankicommunity.github.io',
#   'repo_name': 'ankicommunity.github.io'},
#  {'remote_url': 'https://github.com/ankicommunity/ankidown.git',
#   'repo_name': 'ankidown'},
#  {'remote_url': 'https://github.com/ankicommunity/anki-sync-server',
#   'repo_name': 'anki-sync-server'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/plugin.audio.googleplaymusic.git',
#   'repo_name': 'plugin.audio.googleplaymusic'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/plugin.script.tvtime.git',
#   'repo_name': 'plugin.script.tvtime'},
#  {'remote_url': 'git@github.com:Vikash-Kothary/kodi-cli-python.git',
#   'repo_name': 'kodi-cli-python'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/plugin.video.netflix.git',
#   'repo_name': 'plugin.video.netflix'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/react-iframe',
#   'repo_name': 'react-iframe'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/react-bootstrap',
#   'repo_name': 'react-bootstrap'},
#  {'remote_url': 'git@github.com:VikashKothary/travel-map-python.git',
#   'repo_name': 'travel-map-python'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/react-pomodoro.git',
#   'repo_name': 'react-pomodoro'},
#  {'repo_name': 'pomodoro-calendar'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/swagger-aem',
#   'repo_name': 'swagger-aem'},
#  {'repo_name': 'swagger-myfitnesspal'},
#  {'remote_url': 'https://github.com/orcasgit/python-fitbit',
#   'repo_name': 'python-fitbit'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/university-project-sunka.git',
#   'repo_name': 'university-project-sunka'},
#  {'remote_url': 'https://bitbucket.org/vikashkothary/pracoursework/',
#   'repo_name': ''},
#  {'remote_url': 'https://github.com/Vikash-Kothary/library-jswing.git',
#   'repo_name': 'library-jswing'},
#  {'remote_url': 'https://gitlab.com/VikashKothary/pacman-ai',
#   'repo_name': 'pacman-ai'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/git-subrepo.git',
#   'repo_name': 'git-subrepo'},
#  {'remote_url': 'https://github.com/vikash-kothary/git-org-flow',
#   'repo_name': 'git-org-flow'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/git-multirepo.git',
#   'repo_name': 'git-multirepo'},
#  {'remote_url': 'https://github.com/vikash-kothary/tindetheus',
#   'repo_name': 'tindetheus'},
#  {'remote_url': 'https://gitlab.com/osostogether/messenger-plus',
#   'repo_name': 'messenger-plus'},
#  {'remote_url': 'https://github.com/osostogether/osostogether.github.io',
#   'repo_name': 'osostogether.github.io'},
#  {'remote_url': 'https://github.com/osostogether/background-app',
#   'repo_name': 'background-app'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/jsonresume-theme-boilerplate.git',
#   'repo_name': 'jsonresume-theme-boilerplate'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/jsonresume-theme-business-card.git',
#   'repo_name': 'jsonresume-theme-business-card'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/jsonschema.git',
#   'repo_name': 'jsonschema'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/resumeToMarkdown.git',
#   'repo_name': 'resumeToMarkdown'},
#  {'remote_url': 'https://git.corp.adobe.com/informa-ge/informa-migration-aem',
#   'repo_name': 'informa-migration-aem'},
#  {'remote_url': 'https://git.corp.adobe.com/informa-ge/informa-migration-aem',
#   'repo_name': 'informa-migration-aem'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/generator-chrome-extension.git',
#   'repo_name': 'generator-chrome-extension'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/generator-react-native-multi-platform.git',
#   'repo_name': 'generator-react-native-multi-platform'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/generator-open-source-docs.git',
#   'repo_name': 'generator-open-source-docs'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/fullstack',
#   'repo_name': 'fullstack'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/generator-fitbit-app.git',
#   'repo_name': 'generator-fitbit-app'},
#  {'remote_url': 'https://github.com/vikash-kothary/facebox-python',
#   'repo_name': 'facebox-python'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/joplin',
#   'repo_name': 'joplin'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/jobie-api-python.git',
#   'repo_name': 'jobie-api-python'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/hackathon-project-translatify.git',
#   'repo_name': 'hackathon-project-translatify'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/hackathon-project-learnit.git',
#   'repo_name': 'hackathon-project-learnit'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/hackameetup.git',
#   'repo_name': 'hackameetup'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/skynet-ai-frontend.git',
#   'repo_name': 'skynet-ai-frontend'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/hackathon-project-natural-git.git',
#   'repo_name': 'hackathon-project-natural-git'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/veggie-on-rails.git',
#   'repo_name': 'veggie-on-rails'},
#  {'remote_url': 'https://github.com/theomessin/anastasia',
#   'repo_name': 'anastasia'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/hackathon-project-museful.git',
#   'repo_name': 'hackathon-project-museful'},
#  {'remote_url': 'https://github.com/VikashKothary/hacktrain6-gemini',
#   'repo_name': 'hacktrain6-gemini'},
#  {'repo_name': 'adobe-lunchandlearn-python'},
#  {'remote_url': 'https://github.com/adobe/aem-spa-project-archetype',
#   'repo_name': 'aem-spa-project-archetype'},
#  {'remote_url': 'https://git.corp.adobe.com/kothary/aem-developer-bootstrap.git',
#   'repo_name': 'aem-developer-bootstrap'},
#  {'repo_name': 'bastien-poc'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/aem-sass-compiler',
#   'repo_name': 'aem-sass-compiler'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/aem-cmd',
#   'repo_name': 'aem-cmd'},
#  {'remote_url': 'https://git.corp.adobe.com/vikash-kothary-work/acs-aem-cli.git',
#   'repo_name': 'acs-aem-cli'},
#  {'remote_url': 'https://github.com/jlentink/aem', 'repo_name': 'aem'},
#  {'remote_url': 'https://git.corp.adobe.com/kothary/aem-development-guidelines.git',
#   'repo_name': 'aem-development-guidelines'},
#  {'remote_url': 'https://git.corp.adobe.com/informa-ge/informa-migration-wiki',
#   'repo_name': 'informa-migration-wiki'},
#  {'remote_url': 'https://git.corp.adobe.com/informa-ge/informa-migration-designs',
#   'repo_name': 'informa-migration-designs'},
#  {'remote_url': 'https://git.corp.adobe.com/informa-ge/informa-migration-aem',
#   'repo_name': 'informa-migration-aem'},
#  {'remote_url': 'https://git.corp.adobe.com/informa-ge/informa-migration-backend',
#   'repo_name': 'informa-migration-backend'},
#  {'remote_url': 'https://git.corp.adobe.com/vikash-kothary-work/acs-emea-awards.git',
#   'repo_name': 'acs-emea-awards'},
#  {'remote_url': 'https://git.corp.adobe.com/vikash-kothary-work/lazybones-aem-templates.git',
#   'repo_name': 'lazybones-aem-templates'},
#  {'remote_url': 'https://git.corp.adobe.com/vikash-kothary-work/acs-confluence-wiki',
#   'repo_name': 'acs-confluence-wiki'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/productivity-app-android.git',
#   'repo_name': 'productivity-app-android'},
#  {'remote_url': 'https://git.corp.adobe.com/aem-enablement/aem65livetrials.git',
#   'repo_name': 'aem65livetrials'},
#  {'remote_url': 'https://git.corp.adobe.com/vikash-kothary-work/aem-6.5-live-trials',
#   'repo_name': 'aem-6.5-live-trials'},
#  {'remote_url': 'https://git.corp.adobe.com/vikash-kothary-work/SJCImplementors.git',
#   'repo_name': 'SJCImplementors'},
#  {'remote_url': 'https://git.corp.adobe.com/kothary/adls-aem-training.git',
#   'repo_name': 'adls-aem-training'},
#  {'remote_url': 'https://github.com/vikash-kothary/ocean-jobs',
#   'repo_name': 'ocean-jobs'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/ocean-obtain-python.git',
#   'repo_name': 'ocean-obtain-python'},
#  {'remote_url': 'https://gitlab.com/VikashKothary/life-app-android',
#   'repo_name': 'life-app-android'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/looking-glass-rpg.git',
#   'repo_name': 'looking-glass-rpg'},
#  {'remote_url': 'https://git.corp.adobe.com/kothary/acs-aem-docker.git',
#   'repo_name': 'acs-aem-docker'},
#  {'remote_url': 'https://gitlab.com/VikashKothary/vikash-kothary-github-io',
#   'repo_name': 'vikash-kothary-github-io'},
#  {'remote_url': 'https://github.com/Vikash-Kothary/ocean-accounts-python.git',
#   'repo_name': 'ocean-accounts-python'}]

# %%
# Get organisations
exclude_orgs = ['Robotics-KCL', 'ankicommunity', 'theperfectionistorg', 'osostogether']
my_orgs = []
for orgs in user.get_orgs():
    if (orgs.login not in exclude_orgs):
        my_orgs.append(orgs.login)
pprint(my_orgs)
# Out:
# ['Vikash-Kothary']

# %%
# Get remote repos in organisation
org_name = my_orgs[-1]
org = github.get_organization(org_name)
my_repos = []
for repos in org.get_repos():
    my_repos.append(repos.name)
# pprint(my_repos)

# %%
# Find missing local repos
exlude_repo_names = []
remote_repo_names = my_repos
local_repos_names = [repo['repo_name'] for repo in my_local_repos]
my_missing_repos = list(set(remote_repo_names) - set(local_repos_names))
for missing_repo in my_missing_repos:
    if missing_repo not in exlude_repo_names:
        print(missing_repo)
# Out:
# Awesome-CV
# create-openapi-repo
# org-settings
# osos-file-formats
# docker-tor-rotator
# plugin.video.hotstar2
# generator-html5-boilerplate
# docker-gitlab
# hackathon-project-mail-plus
# vikashkothary-frontend
# hackathon-project-my-pet-parrot
# university-project-languine
# docker-nginx
# plugin.video.skygo
# resumeToPDF
# git-lfs-flow
# hackathon-project-now
# ocean-email
# financial-freedom-python
# git-forked-issues
# coursera-applied-data-science
# hackathon-project-wheelx
# hackathon-project-square-chat
# everyone-active-web
# osos-dating
# hackathon-project-muzact
# jobie-app-react
# acs-coding-standards
# git-wiki-flow
# british-express-python
# generator-yeoman-generator
# ocean-social-typescript
# plugin.video.netflixbmc
# lazybones
# university-project-walk
# hackathon-project-movie-narrator
# ansible-kubespray
# openapi-cli-generator
# skynet-ai-backend
# docker-jenkins
# notion-py
# javascript
# plugin.video.crunchyroll
# youtube-upload
# docker-backup
# ocean-format-recipe
# resume-cli
# ocean-voices
# plugin.video.hotstar
# docker-alpine
# market-information-service
# docker-node
# generator-python-package
# docker-plex
# kcl-tech-android-workshop
# python-myfitnesspal
# resume-schema
# docker-ngrok
# dotyaml
# git-project-gantt
# docker-ubuntu
# osos-cinema
# react-contextmenu
# generator-kotlin-multi-platform
# coursera-deep-learning
# aem-admin-extension-new-console
# redhat-ansible-workshop
# docker-mailslurper
# university-project-kinba
# LanguineCMS
# vikash-kothary.github.io
# ocean-faces
# ocean-dating-typescript
# kanbanist
# docker-gollum

# %%
# GitLab Login
gitlab = Gitlab('https://gitlab.com', private_token=GITLAB_TOKEN)
gitlab.auth()

# %%
groups = gitlab.groups.list()
for group in groups:
    if group.name == 'Vikash-Kothary':
        organisation = group
parent_id = organisation.id

# subgroups = organisation.subgroups.list()
# for subgroup in subgroups:
#     print(subgroup)
# Out:
# 3834489

# %%
# Get groups
my_groups = []
for file in my_files:
    my_groups.append(file.split('/')[3])
my_groups = list(set(my_groups))
pprint(my_groups)
# Out:
# ['..']

# %%
group = gl.groups.create({'name': 'Adobe', 'path': ''})
